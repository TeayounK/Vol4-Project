# %%
import numpy as np
from scipy.integrate import solve_ivp
from scipy.integrate import solve_bvp
import matplotlib.pyplot as plt
import scipy.linalg as la

# %%
tau = .085
beta = 0.7
gamma = 0.36
alpha = 0.75
delta = .25

# Make the ODE function
def ode(t, y):
    '''defines the ode system'''
    return np.array([tau*(gamma*y[1] + delta*y[0]) + tau*(alpha*y[2] + beta*y[0]) - beta*y[0]-delta*y[0],
                     alpha*y[2] + beta*y[0] - gamma*y[1] - tau*(alpha*y[2] + beta*y[0]),
                     gamma*y[1] - alpha*y[2] - tau*(gamma*y[1] + delta*y[0]) + delta*y[0]])
# Make the time domain
t_span = (0, 10)
# Set the initial conditions
y0 = np.array([1,0,0])
# solve the system
sol = solve_ivp(ode, t_span, y0, max_step=0.05)

# Plot solution and compare to actual
plt.subplot(111)
plt.plot(sol.t,sol.y[0], label="G")
plt.plot(sol.t,sol.y[1], label="B")
plt.plot(sol.t,sol.y[2], label="I")
plt.legend()
plt.ylabel("Percent of total capital")
plt.xlabel("Time (years)")
plt.title("New Govenment, New Money")

plt.savefig("new_govt_money.png", dpi = 300)

# %%
tau = .085
beta = 0.7
gamma = 0.36
alpha = 0.75
delta = .25

# Make the ODE function
def ode(t, y):
    '''defines the ode system'''
    return np.array([tau*(gamma*y[1] + delta*y[0]) + tau*(alpha*y[2] + beta*y[0]) - beta*y[0]-delta*y[0],
                     alpha*y[2] + beta*y[0] - gamma*y[1] - tau*(alpha*y[2] + beta*y[0]),
                     gamma*y[1] - alpha*y[2] - tau*(gamma*y[1] + delta*y[0]) + delta*y[0]])
# Make the time domain
t_span = (0, 10)
# Set the initial conditions
y0 = np.array([10.,28.,90.])
y0 /= la.norm(y0,1)
# solve the system
sol = solve_ivp(ode, t_span, y0, max_step=0.05)

# Plot solution and compare to actual
plt.subplot(111)
plt.plot(sol.t,sol.y[0], label="G")
plt.plot(sol.t,sol.y[1], label="B")
plt.plot(sol.t,sol.y[2], label="I")
plt.legend()
plt.ylabel("Percent of total capital")
plt.xlabel("Time (years)")
plt.title("Starting from Current US Values")

plt.savefig("current_vals1.png", dpi = 300)

# %%
tau_i = .085
tau_b = .21
beta = 0.7
gamma = 0.5
alpha = 0.75
delta = .25

# Make the ODE function
def ode(t, y):
    '''defines the ode system'''
    return np.array([tau_i*(gamma*y[1] + delta*y[0]) + tau_b*(alpha*y[2] + beta*y[0]) - beta*y[0]-delta*y[0],
                     alpha*y[2] + beta*y[0] - gamma*y[1] - tau_b*(alpha*y[2] + beta*y[0]),
                     gamma*y[1] - alpha*y[2] - tau_i*(gamma*y[1] + delta*y[0]) + delta*y[0]])
# Make the time domain
t_span = (0, 10)
# Set the initial conditions
y0 = np.array([10.,28.,90.])
y0 /= la.norm(y0,1)
# solve the system
sol = solve_ivp(ode, t_span, y0, max_step=0.05)

# Plot solution and compare to actual
plt.subplot(111)
plt.plot(sol.t,sol.y[0], label="G")
plt.plot(sol.t,sol.y[1], label="B")
plt.plot(sol.t,sol.y[2], label="I")
plt.legend()
plt.ylabel("Percent of total capital")
plt.xlabel("Time (years)")
plt.title("Starting from Current US Values, 21% Business Tax")

plt.savefig("current_vals2.png", dpi = 300)

# %%
tau_i = .085
tau_b = .5
beta = 0.7
gamma = 0.5
alpha = 0.75
delta = .25

# Make the ODE function
def ode(t, y):
    '''defines the ode system'''
    return np.array([tau_i*(gamma*y[1] + delta*y[0]) + tau_b*(alpha*y[2] + beta*y[0]) - beta*y[0]-delta*y[0],
                     alpha*y[2] + beta*y[0] - gamma*y[1] - tau_b*(alpha*y[2] + beta*y[0]),
                     gamma*y[1] - alpha*y[2] - tau_i*(gamma*y[1] + delta*y[0]) + delta*y[0]])
# Make the time domain
t_span = (0, 10)
# Set the initial conditions
y0 = np.array([10.,28.,90.])
y0 /= la.norm(y0,1)
# solve the system
sol = solve_ivp(ode, t_span, y0, max_step=0.05)

# Plot solution and compare to actual
plt.subplot(111)
plt.plot(sol.t,sol.y[0], label="G")
plt.plot(sol.t,sol.y[1], label="B")
plt.plot(sol.t,sol.y[2], label="I")
plt.legend()
plt.ylabel("Percent of total capital")
plt.xlabel("Time (years)")
plt.title("Starting from Current US Values, 50% Business Tax")

plt.savefig("current_vals3.png", dpi = 300)

# %%
tau_i = .085
tau_b = .8
beta = 0.7
gamma = 0.5
alpha = 0.75
delta = .25

# Make the ODE function
def ode(t, y):
    '''defines the ode system'''
    return np.array([tau_i*(gamma*y[1] + delta*y[0]) + tau_b*(alpha*y[2] + beta*y[0]) - beta*y[0]-delta*y[0],
                     alpha*y[2] + beta*y[0] - gamma*y[1] - tau_b*(alpha*y[2] + beta*y[0]),
                     gamma*y[1] - alpha*y[2] - tau_i*(gamma*y[1] + delta*y[0]) + delta*y[0]])
# Make the time domain
t_span = (0, 10)
# Set the initial conditions
y0 = np.array([10.,28.,90.])
y0 /= la.norm(y0,1)
# solve the system
sol = solve_ivp(ode, t_span, y0, max_step=0.05)

# Plot solution and compare to actual
plt.subplot(111)
plt.plot(sol.t,sol.y[0], label="G")
plt.plot(sol.t,sol.y[1], label="B")
plt.plot(sol.t,sol.y[2], label="I")
plt.legend()
plt.ylabel("Percent of total capital")
plt.xlabel("Time (years)")
plt.title("Starting from Current US Values, 50% Business Tax")

# plt.savefig("current_vals3.png", dpi = 300)
# Out:
# Text(0.5, 1.0, 'Starting from Current US Values, 50% Business Tax')
